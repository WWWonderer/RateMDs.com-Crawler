# %% [markdown]
# # Description

# %% [markdown]
#  The goal of this notebook is to find the better doctors in Canada on a site called [RateMDs](https://www.ratemds.com), and avoid being victim of bad doctor practices which is unfortunately not uncommon. You are welcome to modify the code to suit your needs. The project is inspired by [this repository](https://github.com/rbanerjee3) of Rupam Anup Banerjee.

# %% [markdown]
# ## How does it work?

# %% [markdown]
# This program has 2 components:
# 1. crawler
# 2. analyzer
#
# The crawler is used to retrieve all the specialty doctors in a region from ratemds.com, so the analyzer can process filtering based on rating and disease keywords. The crawler will also save the retrieved doctor information to a csv file as it can take a lot of time to crawl (we respect the site's throughput and are intentionally slow).
#
# The crawler registers the following information in RateMDs:
# * Name of the doctor
# * Specialty
# * Star-rating
# * No. of reviews
# * Star-ratings of reviews
# * Review contents
#
# You need to provide the following information to the crawler:
# * Doctor location
# * Doctor specialty
#
# The analyzer filters doctors based on rating and the comments by other patients. You need to provide the following information to the analyzer:
# * Number of candidate doctors
# * Disease keywords
#
# The number of candidate doctors indicate how many candidate doctors will be retrieved based on rating, while disease keywords will help find doctors who have practised treatment of your specific disease. For example, an ophthalmologist can mainly do corneal vs retinal diseases.
#
# You can also provide some additional information to the analyzer:
# * Minimum number of reviews
# * Minimum overall rating threshold
# * Number of top and bottom ratings to analyze
#
# You can also optionally ask ChatGPT to give a summary of the filtered doctors based on patient comments. This however requires a ChatGPT API key and you need to pay OpenAI for their API.

# %% [markdown]
# ## Available locations and doctor specialties

# %%
avail_locations = {
    "montreal" : "qc/montreal/",
    "toronto" : "on/toronto/",
    "vancouver" : "bc/vancouver/"
}

avail_specialties = {
    "acupuncturist": "acupuncturist/",
    "addiction medicine specialist": "addiction-medicine/",
    "allergist / immunologist": "allergist-immunologist/",
    "allergist": "allergist-immunologist/",
    "immunologist": "allergist-immunologist/",
    "anesthesiologist": "anesthesiologist/",
    "audiologist": "audiologist/",
    "bariatric / weight loss specialist": "bariatric-weight-loss/",
    "bariatric": "bariatric-weight-loss/",
    "weight loss specialist": "bariatric-weight-loss/",
    "cardiologist": "cardiologist/",
    "cardiothoracic surgeon": "cardiothoracic-surgeon/",
    "chiropractor": "chiropractor/",
    "colorectal surgeon / proctologist": "colorectal-proctologist/",
    "colorectal surgeon": "colorectal-proctologist/",
    "proctologist": "colorectal-proctologist/",
    "dentist": "dentist/",
    "dermatologist": "dermatologist/",
    "dietitian": "dietitian/",
    "emergency room doctor": "emergency-critical/",
    "endocrinologist": "endocrinologist/",
    "endodontist": "endodontist",
    "family doctor / general practitioner": "family-gp/",
    "family doctor": "family-gp/",
    "general practitioner": "family-gp/",
    "gastroenterologist": "gastroenterologist/",
    "general surgeon": "surgeon-general/",
    "geneticist": "geneticist/",
    "gynecologists and obstetricians (obgyn)": "gynecologist-obgyn/",
    "gynecologist": "gynecologist-obgyn/",
    "obstetrician": "gynecologist-obgyn/",
    "obgyn": "gynecologist-obgyn/",
    "homeopath": "homeopath/",
    "infectious disease specialist": "infectious-disease/",
    "internist / geriatrician": "internist-geriatrician/",
    "internist": "internist-geriatrician/",
    "geriatrician": "internist-geriatrician/",
    "massage therapist": "registered-massage-therapist/",
    "midwife": "midwife/",
    "naturopath": "naturopath/",
    "nephrologist": "nephrologist/",
    "neurologist": "neurologist/",
    "neurosurgeon": "neurosurgeon/",
    "nurse practitioner": "nurse-practitioner/",
    "occupational therapist": "occupational-therapist/",
    "oncologist / hematologist": "oncologist-hematologist/",
    "oncologist": "oncologist-hematologist/",
    "hematologist": "oncologist-hematologist/",
    "ophthalmologist": "ophthalmologist/",
    "optometrist": "optometrist/",
    "oral surgeon": "oral-surgeon/",
    "orthodontist": "orthodontist/",
    "orthopedic surgeon": "orthopedics-sports/",
    "osteopath": "osteopath/",
    "otolaryngologist (ent)": "ear-nose-and-throat-ent/",
    "otolaryngologist": "ear-nose-and-throat-ent/",
    "ent": "ear-nose-and-throat-ent/",
    "pain management specialist / physical therapist": "pain-mgmt-physical-rehab/",
    "pain management specialist": "pain-mgmt-physical-rehab/",
    "pain medicine specialist": "pain-medicine-specialist/",
    "pathologist": "pathologist/",
    "pediatrician": "pediatrician/",
    "perinatologist / maternal-fetal medicine specialist": "perinatologist-maternal-fetal-medicine/",
    "perinatologist": "perinatologist-maternal-fetal-medicine/",
    "maternal-fetal medicine specialist": "perinatologist-maternal-fetal-medicine/",
    "periodontist": "periodontist/",
    "physiatrist / physical medicine & rehabilitation": "physiatrist-physical-medicine-rehabilitation/",
    "physiatrist": "physiatrist-physical-medicine-rehabilitation/",
    "physical medicine & rehabilitation": "physiatrist-physical-medicine-rehabilitation/",
    "physical therapist / physiotherapist": "physical-therapist-physiotherapist/",
    "physical therapist": "physical-therapist-physiotherapist/",
    "physiotherapist": "physical-therapist-physiotherapist/",
    "physician assistant": "physician-assistant/",
    "plastic / cosmetic surgeon, physician": "cosmetic-plastic-surgeon/",
    "plastic": "cosmetic-plastic-surgeon/",
    "cosmetic surgeon, physician": "cosmetic-plastic-surgeon/",
    "podiatrist": "podiatrist/",
    "psychiatrist": "psychiatrist/",
    "psychologist": "psychologist/",
    "pulmonologist": "pulmonologist/",
    "radiation oncologist": "radiation-oncologist/",
    "radiologist": "radiologist/",
    "reproductive endocrinologist": "reproductive-endocrinologist/",
    "rheumatologist": "rheumatologist/",
    "sleep doctor": "sleep-disorders/",
    "sports medicine physician": "sports-medicine-physicians/",
    "therapist": "therapist/",
    "urogynecologist": "urogynecologist/",
    "urologist": "urologist/",
    "vascular surgeon / phlebologist": "vascular-phlebologist/",
    "vascular surgeon": "vascular-phlebologist/",
    "phlebologist": "vascular-phlebologist/"
}

# %% [markdown]
# # Libraries

# %%
#Import Webscraping libraries
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException, TimeoutException

#Import Data structure libraries
import pandas as pd

#Other libraries
from time import sleep

# %% [markdown]
# # Parameters

# %%
# CRAWLER PARAMETERS
DOCTOR_LOCATION = "Montreal"
DOCTOR_SPECIALTY = "ophthalmologist"

# ANALYZER PARAMETERS
DISEASE_KEYWORDS = ["diabetic", "diabetes", "retinopathy", "macular degeneration", "retina", "diabétique", "diabète", "rétinopathie", "dégénérescence maculaire", "rétine"]
NUM_DOCTORS_TO_RETRIEVE = 50
NUM_TOP_AND_BOTTOM_REVIEWS_TO_ANALYZE = 3
MIN_NUM_RATINGS_THRESHOLD = 5
MIN_OVERALL_RATING_THRESHOLD = 4

# OPTIONAL PARAMETERS
OPENAI_API_KEY = ""

assert DOCTOR_LOCATION.lower() in avail_locations.keys(), "Please provide a valid location. By default, only Montreal, Toronto and Vancouver are available. Modify <avail_locations> above to add more."
assert DOCTOR_SPECIALTY.lower() in avail_specialties.keys(), "Please provide a valid specialty. Check the options above."

# SYSTEM PARAMETERS
IGNORED_EXCEPTIONS = (NoSuchElementException, StaleElementReferenceException)
WEBDRIVER_WAIT_TIME = 10
WEBDRIVER_MAX_RETRY = 5

# %% [markdown]
# ## Crawler code

# %%
url = f"https://www.ratemds.com/best-doctors/{avail_locations[DOCTOR_LOCATION.lower()]}{avail_specialties[DOCTOR_SPECIALTY.lower()]}"

# %%
def create_doctor_dataframe():
    '''Create data structure for crawled information'''
    return pd.DataFrame(columns=[
        'Doctor name',
        'Specialty',
        'Overall rating',
        'No. of reviews',
        'Reviews',
        'Review rating'
    ])

def launch_chrome(url):
    '''Launch a Chrome Session'''
    driver=webdriver.Chrome()
    driver.implicitly_wait(WEBDRIVER_WAIT_TIME)
    driver.get(url)
    return driver

def _stable_find_page_doctors(page_doctor_list):
    '''Extract single doctor reviews per page'''
    page_doctors = []
    for i in range(WEBDRIVER_MAX_RETRY):
        try:
            for doctor in page_doctor_list:
                page_doctors.append((doctor.text, doctor.get_attribute('href')))
            break
        except StaleElementReferenceException:
            sleep(1)
            continue
    return page_doctors

def stable_find_doctor_list(driver):
    '''Find all doctor names and urls for the given region and specialty'''
    doctors = []
    while True:
        for i in range(WEBDRIVER_MAX_RETRY):
            try:
                page_doctor_list = WebDriverWait(driver, WEBDRIVER_WAIT_TIME, ignored_exceptions=IGNORED_EXCEPTIONS).until(
                    EC.presence_of_all_elements_located((By.CLASS_NAME, 'search-item-doctor-name'))
                )
                page_doctors = _stable_find_page_doctors(page_doctor_list)
                doctors += page_doctors
                next_page_link = driver.find_element(By.XPATH, '//a[@aria-label="Next page"]').get_attribute('href')
                driver.get(next_page_link)
                sleep(1)
                break
            except StaleElementReferenceException:
                sleep(1)
                continue
            except NoSuchElementException:
                return doctors

def stable_find_doctor_info(driver, url):
    '''Extract single doctor general info'''
    driver.get(url)
    sleep(1)
    for i in range(WEBDRIVER_MAX_RETRY):
        try:
            doctor_banner_panel = WebDriverWait(driver, WEBDRIVER_WAIT_TIME, ignored_exceptions=IGNORED_EXCEPTIONS).until(
                EC.presence_of_element_located((By.CLASS_NAME, 'doctor-banner-panel'))
            )
            specialty = WebDriverWait(doctor_banner_panel, WEBDRIVER_WAIT_TIME, ignored_exceptions=IGNORED_EXCEPTIONS).until(
                EC.presence_of_element_located((By.CLASS_NAME, 'search-item-info'))
            ).text
            leave_review = WebDriverWait(doctor_banner_panel, WEBDRIVER_WAIT_TIME, ignored_exceptions=IGNORED_EXCEPTIONS).until(
                EC.presence_of_element_located((By.CLASS_NAME, 'leave-a-review-cta-text'))
            ).text
            if leave_review == 'Be the First to Review!':
                return specialty, '', ''
            rating_and_no_reviews = WebDriverWait(doctor_banner_panel, WEBDRIVER_WAIT_TIME, ignored_exceptions=IGNORED_EXCEPTIONS).until(
                EC.presence_of_element_located((By.CLASS_NAME, 'star-rating-count'))
            ).text
            overall_rating = rating_and_no_reviews[:3]
            no_reviews = rating_and_no_reviews[5:rating_and_no_reviews.find(' review')]
            break
        except StaleElementReferenceException:
            sleep(1)
            continue
        except TimeoutException:
            driver.refresh()
            sleep(1)
            continue

    return specialty, overall_rating, no_reviews

def _get_star_rating(driver):
    '''Extract review star rating'''
    rating = 0
    stars = WebDriverWait(driver, WEBDRIVER_WAIT_TIME, ignored_exceptions=IGNORED_EXCEPTIONS).until(
        EC.presence_of_all_elements_located((By.TAG_NAME, 'svg'))
    )
    for star in stars:
        if star.get_attribute('class') == 'selected': rating += 1
        elif star.get_attribute('class') == 'half': rating += 0.5
    return rating

def _stable_find_page_reviews(page_review_list):
    '''Extract single doctor reviews per page'''
    page_reviews = []
    for i in range(WEBDRIVER_MAX_RETRY):
        try:
            for review in page_review_list:
                star_rating = _get_star_rating(review)
                comment = WebDriverWait(review, WEBDRIVER_WAIT_TIME, ignored_exceptions=IGNORED_EXCEPTIONS).until(
                    EC.presence_of_element_located((By.CLASS_NAME, 'rating-comment-body'))
                ).text
                page_reviews.append((star_rating, comment))
            break
        except StaleElementReferenceException:
            sleep(1)
            continue
    return page_reviews

def stable_find_doctor_reviews(driver):
    '''Extract single doctor reviews'''
    reviews = []
    while True:
        for i in range(WEBDRIVER_MAX_RETRY):
            try:
                page_review_list = WebDriverWait(driver, WEBDRIVER_WAIT_TIME, ignored_exceptions=IGNORED_EXCEPTIONS).until(
                    EC.presence_of_all_elements_located((By.CLASS_NAME, 'rating'))
                )
                page_reviews = _stable_find_page_reviews(page_review_list)
                reviews += page_reviews
                next_page_link = driver.find_element(By.XPATH, '//a[@aria-label="Next page"]').get_attribute('href')
                driver.get(next_page_link)
                sleep(1)
                break
            except StaleElementReferenceException:
                sleep(1)
                continue
            except NoSuchElementException:
                return reviews
            
def register_doctor_info_to_dataframe(dataframe, doctor_name, specialty, overall_rating, no_reviews, reviews):
    '''Register single doctor information to pandas dataframe'''
    for review in reviews:
        dataframe.loc[len(dataframe)] = {
            'Doctor name': doctor_name,
            'Specialty': specialty,
            'Overall rating': overall_rating,
            'No. of reviews': no_reviews,
            'Reviews': review[1],
            'Review rating': review[0]
        }

# %%
print('creating data frame for doctor info...')
doctors_data = create_doctor_dataframe()
driver = launch_chrome(url)
driver.maximize_window()
print(f'extracting list of {DOCTOR_SPECIALTY} in {DOCTOR_LOCATION}...')
doctors = stable_find_doctor_list(driver)
print(f'number of {DOCTOR_SPECIALTY} found: {len(doctors)}.')

for doctor_name, link in doctors:
    print(f'extracting information of {doctor_name}...')
    specialty, overall_rating, no_reviews = stable_find_doctor_info(driver, link)
    print(f'specialty: {specialty}, overall_rating: {overall_rating}, no_reviews: {no_reviews}')
    # no review
    if overall_rating == '' and no_reviews == '':
        no_reviews = 0
        reviews = [('', '')]
    # with review(s)
    else:
        reviews = stable_find_doctor_reviews(driver)
        try:
            assert len(reviews) == int(no_reviews), f"Crawler error: all reviews are not retrieved for {doctor_name}. Extraction omitted, please check manually."
        except AssertionError:
            continue
    print('registering information to dataframe...')
    register_doctor_info_to_dataframe(doctors_data, doctor_name, specialty, overall_rating, no_reviews, reviews)
print('saving data to csv file...')    
doctors_data.to_csv(f'{DOCTOR_SPECIALTY}_{DOCTOR_LOCATION}.csv')
# Out:
# creating data frame for doctor info...
# extracting list of ophthalmologist in Montreal...
# number of ophthalmologist found: 311.
# extracting information of Dr. Marc Mullie...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 267
# registering information to dataframe...
# extracting information of Dr. Avi Wallerstein...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 224
# registering information to dataframe...
# extracting information of Dr. Mona Harrissi Dagher...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 61
# registering information to dataframe...
# extracting information of Dr. Evan Kalin-Hajdu...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 57
# registering information to dataframe...
# extracting information of Dr. Darren L. Albert...
# specialty: Ophthalmologist, overall_rating: 4.8, no_reviews: 188
# registering information to dataframe...
# extracting information of Dr. Pierre Demers...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 47
# registering information to dataframe...
# extracting information of Dr. Samir Jabbour...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 28
# registering information to dataframe...
# extracting information of Dr. Mark Cohen...
# specialty: Ophthalmologist, overall_rating: 4.7, no_reviews: 116
# registering information to dataframe...
# extracting information of Dr. Shawn Cohen...
# specialty: Ophthalmologist, overall_rating: 4.7, no_reviews: 105
# registering information to dataframe...
# extracting information of Dr. Patrick Hamel...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 31
# registering information to dataframe...
# extracting information of Dr. Barbara Teboul...
# specialty: Ophthalmologist, overall_rating: 4.6, no_reviews: 128
# registering information to dataframe...
# extracting information of Dr. Rachel Trussart...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 19
# registering information to dataframe...
# extracting information of Dr. Amer Omar...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 24
# registering information to dataframe...
# extracting information of Dr. Marc Andre Rheaume...
# specialty: Ophthalmologist, overall_rating: 4.8, no_reviews: 30
# registering information to dataframe...
# extracting information of Dr. Mounir Bashour...
# specialty: Ophthalmologist, overall_rating: 4.6, no_reviews: 116
# registering information to dataframe...
# extracting information of Dr. Marino J Discepola...
# specialty: Ophthalmologist, overall_rating: 4.5, no_reviews: 171
# registering information to dataframe...
# extracting information of Dr. Sébastien Olivier...
# specialty: Ophthalmologist, overall_rating: 4.7, no_reviews: 42
# registering information to dataframe...
# extracting information of Dr. Younes Agoumi...
# specialty: Ophthalmologist, overall_rating: 4.7, no_reviews: 51
# registering information to dataframe...
# extracting information of Dr. Michel Gravel...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 15
# registering information to dataframe...
# extracting information of Dr. Patrick Boulos...
# specialty: Ophthalmologist, overall_rating: 4.6, no_reviews: 56
# registering information to dataframe...
# extracting information of Dr. Devinder Cheema...
# specialty: Ophthalmologist, overall_rating: 4.5, no_reviews: 72
# registering information to dataframe...
# extracting information of Dr. David Lederer...
# specialty: Ophthalmologist, overall_rating: 4.6, no_reviews: 49
# registering information to dataframe...
# extracting information of Dr. Chantal Ares...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 16
# registering information to dataframe...
# extracting information of Dr. Nicole Fallaha...
# specialty: Ophthalmologist, overall_rating: 4.8, no_reviews: 20
# registering information to dataframe...
# extracting information of Dr. Conrad C. Kavalec...
# specialty: Ophthalmologist, overall_rating: 4.4, no_reviews: 114
# registering information to dataframe...
# extracting information of Dr. Johanne Menassa...
# specialty: Ophthalmologist, overall_rating: 4.5, no_reviews: 58
# registering information to dataframe...
# extracting information of Dr. Marc Mydlarski...
# specialty: Ophthalmologist, overall_rating: 4.6, no_reviews: 41
# registering information to dataframe...
# extracting information of Dr. Tanguy Boutin...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 16
# registering information to dataframe...
# extracting information of Dr. Chaim Edelstein...
# specialty: Ophthalmologist, overall_rating: 4.3, no_reviews: 172
# registering information to dataframe...
# extracting information of Dr. Richard F. Bergeron...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 14
# registering information to dataframe...
# extracting information of Dr. Manuel Perrier...
# specialty: Ophthalmologist, overall_rating: 4.4, no_reviews: 66
# registering information to dataframe...
# extracting information of Dr. Marie-Josée Aubin...
# specialty: Ophthalmologist, overall_rating: 4.7, no_reviews: 17
# registering information to dataframe...
# extracting information of Dr. Sandra Tcherkezian...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 9
# registering information to dataframe...
# extracting information of Dr. David Silver...
# specialty: Ophthalmologist, overall_rating: 4.3, no_reviews: 58
# registering information to dataframe...
# extracting information of Dr. Paul Thompson...
# specialty: Ophthalmologist, overall_rating: 4.6, no_reviews: 19
# registering information to dataframe...
# extracting information of Dr. Stephane Meere...
# specialty: Ophthalmologist, overall_rating: 4.5, no_reviews: 22
# registering information to dataframe...
# extracting information of Dr. Johanna Choremis...
# specialty: Ophthalmologist, overall_rating: 4.2, no_reviews: 75
# registering information to dataframe...
# extracting information of Dr. George El Achkar...
# specialty: Ophthalmologist, overall_rating: 4.5, no_reviews: 26
# registering information to dataframe...
# extracting information of Dr. Jean-Daniel Arbour...
# specialty: Ophthalmologist, overall_rating: 4.7, no_reviews: 16
# registering information to dataframe...
# extracting information of Dr. Gordon Balazsi...
# specialty: Ophthalmologist, overall_rating: 4.5, no_reviews: 22
# registering information to dataframe...
# extracting information of Dr. Erika Massicotte...
# specialty: Ophthalmologist, overall_rating: 4.7, no_reviews: 15
# registering information to dataframe...
# extracting information of Dr. Julius E. S. Gomolin...
# specialty: Ophthalmologist, overall_rating: 4.4, no_reviews: 40
# registering information to dataframe...
# extracting information of Dr. Jamie Wong...
# specialty: Ophthalmologist, overall_rating: 4.7, no_reviews: 14
# registering information to dataframe...
# extracting information of Dr. Jean-Louis Jacob...
# specialty: Ophthalmologist, overall_rating: 4.7, no_reviews: 13
# registering information to dataframe...
# extracting information of Dr. Conrad Pelletier...
# specialty: Ophthalmologist, overall_rating: 4.8, no_reviews: 11
# registering information to dataframe...
# extracting information of Dr. Ali Hafez...
# specialty: Ophthalmologist, overall_rating: 4.5, no_reviews: 22
# registering information to dataframe...
# extracting information of Dr. Marie Claude Tremblay...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 8
# registering information to dataframe...
# extracting information of Dr. Louis Racine...
# specialty: Ophthalmologist, overall_rating: 4.2, no_reviews: 40
# registering information to dataframe...
# extracting information of Dr. Susan Lindley...
# specialty: Ophthalmologist, overall_rating: 4.6, no_reviews: 18
# registering information to dataframe...
# extracting information of Dr. Eric Fortin...
# specialty: Ophthalmologist, overall_rating: 4.7, no_reviews: 11
# registering information to dataframe...
# extracting information of Dr. Salim Lahoud...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 7
# registering information to dataframe...
# extracting information of Dr. Paul Harasymowycz...
# specialty: Ophthalmologist, overall_rating: 4.3, no_reviews: 32
# registering information to dataframe...
# extracting information of Dr. Melissa Louis...
# specialty: Ophthalmologist, overall_rating: 4.6, no_reviews: 13
# registering information to dataframe...
# extracting information of Dr. Thao Nguyen...
# specialty: Ophthalmologist, overall_rating: 4.4, no_reviews: 18
# registering information to dataframe...
# extracting information of Dr. Denis Tardif...
# specialty: Ophthalmologist, overall_rating: 4.7, no_reviews: 18
# registering information to dataframe...
# extracting information of Dr. Michael Kapusta...
# specialty: Ophthalmologist, overall_rating: 4.0, no_reviews: 83
# registering information to dataframe...
# extracting information of Dr. Francois Codere...
# specialty: Ophthalmologist, overall_rating: 4.3, no_reviews: 23
# registering information to dataframe...
# extracting information of Dr. Jesia Hasan...
# specialty: Ophthalmologist, overall_rating: 4.6, no_reviews: 11
# registering information to dataframe...
# extracting information of Dr. Marcelo Wajszilber...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 7
# registering information to dataframe...
# extracting information of Dr. Brian Arthurs...
# specialty: Ophthalmologist, overall_rating: 4.0, no_reviews: 43
# registering information to dataframe...
# extracting information of Dr. Mikael Sebag...
# specialty: Ophthalmologist, overall_rating: 4.0, no_reviews: 46
# registering information to dataframe...
# extracting information of Dr. Renee Carignan...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 6
# registering information to dataframe...
# extracting information of Dr. Kinda Najem...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 6
# registering information to dataframe...
# extracting information of Dr. Jean Duperre...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 6
# registering information to dataframe...
# extracting information of Dr. Emilie Goodyear...
# specialty: Ophthalmologist, overall_rating: 4.7, no_reviews: 8
# registering information to dataframe...
# extracting information of Dr. Rosanne Superstein...
# specialty: Ophthalmologist, overall_rating: 4.1, no_reviews: 36
# registering information to dataframe...
# extracting information of Dr. Karin Oliver...
# specialty: Ophthalmologist, overall_rating: 4.0, no_reviews: 43
# registering information to dataframe...
# extracting information of Dr. Katarzyna Biernacki...
# specialty: Ophthalmologist, overall_rating: 4.5, no_reviews: 11
# registering information to dataframe...
# extracting information of Dr. Michel Pop...
# specialty: Ophthalmologist, overall_rating: 4.0, no_reviews: 32
# registering information to dataframe...
# extracting information of Dr. Louise Charbonneau...
# specialty: Ophthalmologist, overall_rating: 4.8, no_reviews: 8
# registering information to dataframe...
# extracting information of Dr. Barry S. Kattleman...
# specialty: Ophthalmologist, overall_rating: 4.0, no_reviews: 33
# registering information to dataframe...
# extracting information of Dr. Lys Montas...
# specialty: Ophthalmologist, overall_rating: 4.5, no_reviews: 10
# registering information to dataframe...
# extracting information of Dr. Jacinthe Rouleau...
# specialty: Ophthalmologist, overall_rating: 4.2, no_reviews: 17
# registering information to dataframe...
# extracting information of Dr. Karim Hammamji...
# specialty: Ophthalmologist, overall_rating: 4.6, no_reviews: 9
# registering information to dataframe...
# extracting information of Dr. Daniela Toffoli...
# specialty: Ophthalmologist, overall_rating: 4.3, no_reviews: 14
# registering information to dataframe...
# extracting information of Dr. Michele Mabon...
# specialty: Ophthalmologist, overall_rating: 4.1, no_reviews: 20
# registering information to dataframe...
# extracting information of Dr. Sameh Fanous...
# specialty: Ophthalmologist, overall_rating: 3.8, no_reviews: 61
# registering information to dataframe...
# extracting information of Dr. Luis Ospina...
# specialty: Ophthalmologist, overall_rating: 3.8, no_reviews: 50
# registering information to dataframe...
# extracting information of Dr. Michel Podtetenev...
# specialty: Ophthalmologist, overall_rating: 3.9, no_reviews: 27
# registering information to dataframe...
# extracting information of Dr. Gilles Marcil...
# specialty: Ophthalmologist, overall_rating: 4.4, no_reviews: 9
# registering information to dataframe...
# extracting information of Dr. Laurence Jaworski...
# specialty: Ophthalmologist, overall_rating: 4.4, no_reviews: 9
# registering information to dataframe...
# extracting information of Dr. Girair Basmadjian...
# specialty: Ophthalmologist, overall_rating: 4.1, no_reviews: 16
# registering information to dataframe...
# extracting information of Dr. Michael Quigley...
# specialty: Ophthalmologist, overall_rating: 4.0, no_reviews: 28
# registering information to dataframe...
# extracting information of Dr. Ted (William) Connolly...
# specialty: Ophthalmologist, overall_rating: 4.1, no_reviews: 16
# registering information to dataframe...
# extracting information of Dr. Lucie Khourie...
# specialty: Ophthalmologist, overall_rating: 3.6, no_reviews: 52
# registering information to dataframe...
# extracting information of Dr. Mark Lesk...
# specialty: Ophthalmologist, overall_rating: 4.0, no_reviews: 19
# registering information to dataframe...
# extracting information of Dr. Flavio Rezende...
# specialty: Ophthalmologist, overall_rating: 4.1, no_reviews: 15
# registering information to dataframe...
# extracting information of Dr. John Galic...
# specialty: Ophthalmologist, overall_rating: 3.6, no_reviews: 58
# registering information to dataframe...
# extracting information of Dr. Sonia Callejo...
# specialty: Ophthalmologist, overall_rating: 4.1, no_reviews: 13
# registering information to dataframe...
# extracting information of Dr. H.N. El Saheb...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 4
# registering information to dataframe...
# extracting information of Dr. Elizabeth Gariepy...
# specialty: Ophthalmologist, overall_rating: 3.7, no_reviews: 43
# registering information to dataframe...
# extracting information of Dr. Hady Saheb...
# specialty: Ophthalmologist, overall_rating: 3.5, no_reviews: 50
# registering information to dataframe...
# extracting information of Dr. Jean-Pierre Chartrand...
# specialty: Ophthalmologist, overall_rating: 3.6, no_reviews: 41
# registering information to dataframe...
# extracting information of Dr. Mark Gans...
# specialty: Ophthalmologist, overall_rating: 3.5, no_reviews: 46
# registering information to dataframe...
# extracting information of Dr. Alla Muladzanov...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 4
# registering information to dataframe...
# extracting information of Dr. Harmanjit Singh...
# specialty: Ophthalmologist, overall_rating: 4.7, no_reviews: 5
# registering information to dataframe...
# extracting information of Dr. Marie-Lyne Belair...
# specialty: Ophthalmologist, overall_rating: 4.1, no_reviews: 16
# registering information to dataframe...
# extracting information of Dr. Mariam Aroichane...
# specialty: Ophthalmologist, overall_rating: 4.7, no_reviews: 5
# registering information to dataframe...
# extracting information of Dr. John Chen...
# specialty: Ophthalmologist, overall_rating: 3.4, no_reviews: 54
# registering information to dataframe...
# extracting information of Dr. Tuong-Nam Nguyen...
# specialty: Ophthalmologist, overall_rating: 3.6, no_reviews: 30
# registering information to dataframe...
# extracting information of Dr. Renaud Duval...
# specialty: Ophthalmologist, overall_rating: 4.3, no_reviews: 7
# registering information to dataframe...
# extracting information of Dr. Oscar Kasner...
# specialty: Ophthalmologist, overall_rating: 3.7, no_reviews: 23
# registering information to dataframe...
# extracting information of Dr. Stephen Fichman...
# specialty: Ophthalmologist, overall_rating: 3.4, no_reviews: 44
# registering information to dataframe...
# extracting information of Dr. Gisele Li...
# specialty: Ophthalmologist, overall_rating: 3.9, no_reviews: 10
# registering information to dataframe...
# extracting information of Dr. Laura Segal-Ardman...
# specialty: Ophthalmologist, overall_rating: 4.2, no_reviews: 7
# registering information to dataframe...
# extracting information of Dr. Mila Oh...
# specialty: Ophthalmologist, overall_rating: 4.4, no_reviews: 7
# registering information to dataframe...
# extracting information of Dr. Katie Luneau...
# specialty: Ophthalmologist, overall_rating: 4.1, no_reviews: 7
# registering information to dataframe...
# extracting information of Dr. Frenette Benoit...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 4
# registering information to dataframe...
# extracting information of Dr. Ghassan Cordahi...
# specialty: Ophthalmologist, overall_rating: 3.3, no_reviews: 45
# registering information to dataframe...
# extracting information of Dr. Annick Mwilambwe...
# specialty: Ophthalmologist, overall_rating: 3.3, no_reviews: 38
# registering information to dataframe...
# extracting information of Dr. Robert Koenekoop...
# specialty: Ophthalmologist, overall_rating: 3.1, no_reviews: 87
# registering information to dataframe...
# extracting information of Dr. Alexandre Plouznikoff...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 3
# registering information to dataframe...
# extracting information of Dr. Francine Wein...
# specialty: Ophthalmologist, overall_rating: 2.9, no_reviews: 99
# registering information to dataframe...
# extracting information of Dr. Jean Deschenes...
# specialty: Ophthalmologist, overall_rating: 3.3, no_reviews: 24
# registering information to dataframe...
# extracting information of Dr. Pierre Labelle...
# specialty: Ophthalmologist, overall_rating: 3.8, no_reviews: 10
# registering information to dataframe...
# extracting information of Dr. marc B. Mydlarski...
# specialty: Ophthalmologist, overall_rating: 4.0, no_reviews: 6
# registering information to dataframe...
# extracting information of Dr. Hady El-Saheb...
# specialty: Ophthalmologist, overall_rating: 4.8, no_reviews: 3
# registering information to dataframe...
# extracting information of Dr. Louis A. Corriveau...
# specialty: Ophthalmologist, overall_rating: 2.9, no_reviews: 54
# registering information to dataframe...
# extracting information of Dr. Sheila Huang...
# specialty: Ophthalmologist, overall_rating: 3.7, no_reviews: 8
# registering information to dataframe...
# extracting information of Dr. Paul Thomson...
# specialty: Ophthalmologist, overall_rating: 4.6, no_reviews: 3
# registering information to dataframe...
# extracting information of Dr. Eugene N Hladky...
# specialty: Ophthalmologist, overall_rating: 4.6, no_reviews: 3
# registering information to dataframe...
# extracting information of Dr. Michel Paquin...
# specialty: Ophthalmologist, overall_rating: 4.0, no_reviews: 5
# registering information to dataframe...
# extracting information of Dr. Marie Carole Boucher...
# specialty: Ophthalmologist, overall_rating: 3.3, no_reviews: 14
# registering information to dataframe...
# extracting information of Dr. Ta To Quyen...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 2
# registering information to dataframe...
# extracting information of Dr. Marie Eve Gray...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 2
# registering information to dataframe...
# extracting information of Dr. Francois Coderre...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 2
# registering information to dataframe...
# extracting information of Dr. Marie Veillette...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 2
# registering information to dataframe...
# extracting information of Dr. Rogerio Alvès-Costa...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 2
# registering information to dataframe...
# extracting information of Dr. Barry Silver...
# specialty: Ophthalmologist, overall_rating: 3.0, no_reviews: 27
# registering information to dataframe...
# extracting information of Dr. luong C. Nguyen...
# specialty: Ophthalmologist, overall_rating: 4.1, no_reviews: 4
# registering information to dataframe...
# extracting information of Dr. Frederic Lord...
# specialty: Ophthalmologist, overall_rating: 2.8, no_reviews: 41
# registering information to dataframe...
# extracting information of Dr. Mona Bergevin...
# specialty: Ophthalmologist, overall_rating: 4.5, no_reviews: 5
# registering information to dataframe...
# extracting information of Dr. Marian Zaharia...
# specialty: Ophthalmologist, overall_rating: 3.0, no_reviews: 22
# registering information to dataframe...
# extracting information of Dr. Daniel Desjardins...
# specialty: Ophthalmologist, overall_rating: 4.0, no_reviews: 4
# registering information to dataframe...
# extracting information of Dr. Kk Lim...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 2
# registering information to dataframe...
# extracting information of Dr. Marc Ganz...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 2
# registering information to dataframe...
# extracting information of Dr. Christine Corriveau...
# specialty: Ophthalmologist, overall_rating: 4.9, no_reviews: 2
# registering information to dataframe...
# extracting information of Dr. Olivier Lasnier...
# specialty: Ophthalmologist, overall_rating: 3.8, no_reviews: 5
# registering information to dataframe...
# extracting information of Dr. Joel Rosen...
# specialty: Ophthalmologist, overall_rating: 3.1, no_reviews: 18
# registering information to dataframe...
# extracting information of Dr. Oskar Kasner...
# specialty: Ophthalmologist, overall_rating: 3.9, no_reviews: 4
# registering information to dataframe...
# extracting information of Dr. Ghassan Georges El-Achkar...
# specialty: Ophthalmologist, overall_rating: 3.9, no_reviews: 4
# registering information to dataframe...
# extracting information of Dr. Quynh Nguyen...
# specialty: Ophthalmologist, overall_rating: 2.9, no_reviews: 21
# registering information to dataframe...
# extracting information of Dr. Andrée Quevillon...
# specialty: Ophthalmologist, overall_rating: 3.0, no_reviews: 14
# registering information to dataframe...
# extracting information of Dr. Isabelle Brunette...
# specialty: Ophthalmologist, overall_rating: 3.4, no_reviews: 6
# registering information to dataframe...
# extracting information of Dr. Bryan Arthurs...
# specialty: Ophthalmologist, overall_rating: 3.6, no_reviews: 5
# registering information to dataframe...
# extracting information of Dr. Luong Nguyen...
# specialty: Ophthalmologist, overall_rating: 2.6, no_reviews: 56
# registering information to dataframe...
# extracting information of Dr. Michel Laflamme...
# specialty: Ophthalmologist, overall_rating: 3.7, no_reviews: 4
# registering information to dataframe...
# extracting information of Dr. Eugene Edelstein...
# specialty: Ophthalmologist, overall_rating: 2.8, no_reviews: 16
# registering information to dataframe...
# extracting information of Dr. M Flanders...
# specialty: Ophthalmologist, overall_rating: 3.0, no_reviews: 10
# registering information to dataframe...
# extracting information of Dr. Allan Coffey...
# specialty: Ophthalmologist, overall_rating: 3.9, no_reviews: 3
# registering information to dataframe...
# extracting information of Dr. Flavio Rezende Flavio...
# specialty: Ophthalmologist, overall_rating: 3.6, no_reviews: 4
# registering information to dataframe...
# extracting information of Dr. Francine Mathieu-Millaire...
# specialty: Ophthalmologist, overall_rating: 2.2, no_reviews: 93
# registering information to dataframe...
# extracting information of Dr. W Connolly...
# specialty: Ophthalmologist, overall_rating: 2.6, no_reviews: 18
# registering information to dataframe...
# extracting information of Dr. Leon Solomon...
# specialty: Ophthalmologist, overall_rating: 2.7, no_reviews: 17
# registering information to dataframe...
# extracting information of Dr. Emile Svarc...
# specialty: Ophthalmologist, overall_rating: 3.0, no_reviews: 7
# registering information to dataframe...
# extracting information of Dr. Eugene Hladky...
# specialty: Ophthalmologist, overall_rating: 2.7, no_reviews: 13
# registering information to dataframe...
# extracting information of Dr. Ayesha Khan...
# specialty: Ophthalmologist, overall_rating: 2.6, no_reviews: 16
# registering information to dataframe...
# extracting information of Dr. Sophie Leduc...
# specialty: Ophthalmologist, overall_rating: 2.5, no_reviews: 18
# registering information to dataframe...
# extracting information of Dr. David Silver...
# specialty: Ophthalmologist, overall_rating: 4.1, no_reviews: 2
# registering information to dataframe...
# extracting information of Dr. Hélène Boisjoly...
# specialty: Ophthalmologist, overall_rating: 3.6, no_reviews: 3
# registering information to dataframe...
# extracting information of Dr. Jacques Salem...
# specialty: Ophthalmologist, overall_rating: 2.4, no_reviews: 17
# registering information to dataframe...
# extracting information of Dr. Pearl Youhnovska...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. El Achkar...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. César Hérédia...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Louis Duperre...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Francoise Noel...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Francois Lavigne...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 2
# registering information to dataframe...
# extracting information of Dr. Lucie Groleau...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Serge Larin...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Helene Lalande...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. David Silver...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Kamil Nasr...
# specialty: Ophthalmologist, overall_rating: 4.5, no_reviews: 3
# registering information to dataframe...
# extracting information of Dr. Pauline Noel...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Alan Coffee...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Naomi Hasagawa...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Jack Wise...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Al Adel Fadwa...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Marcel Tanenbaum...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Nima Shahi...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Cheema Dev...
# specialty: Ophthalmologist, overall_rating: 3.8, no_reviews: 2
# registering information to dataframe...
# extracting information of Dr. Ghassan Cordahi...
# specialty: Ophthalmologist, overall_rating: 4.8, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Dan Boghen...
# specialty: Ophthalmologist, overall_rating: 4.8, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Kurt Schirmer...
# specialty: Ophthalmologist, overall_rating: 4.8, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Marc-Andre Rheaume...
# specialty: Ophthalmologist, overall_rating: 4.8, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Luong C Nguyen...
# specialty: Ophthalmologist, overall_rating: 4.8, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Nabil Saheb...
# specialty: Ophthalmologist, overall_rating: 4.8, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Francine Millaire...
# specialty: Ophthalmologist, overall_rating: 2.2, no_reviews: 12
# registering information to dataframe...
# extracting information of Dr. Majed Aloitabi...
# specialty: Ophthalmologist, overall_rating: 2.7, no_reviews: 5
# registering information to dataframe...
# extracting information of Dr. Elizabeth Gariépy...
# specialty: Ophthalmologist, overall_rating: 3.0, no_reviews: 3
# registering information to dataframe...
# extracting information of Dr. J. Galic...
# specialty: Ophthalmologist, overall_rating: 2.8, no_reviews: 4
# registering information to dataframe...
# extracting information of Dr. A Yoscovitc...
# specialty: Ophthalmologist, overall_rating: 3.3, no_reviews: 2
# registering information to dataframe...
# extracting information of Dr. Parent Raymonde...
# specialty: Ophthalmologist, overall_rating: 3.8, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Jeannine Mechaly-Chokron...
# specialty: Ophthalmologist, overall_rating: 2.2, no_reviews: 4
# registering information to dataframe...
# extracting information of Dr. Jocelyne Brochu...
# specialty: Ophthalmologist, overall_rating: 2.0, no_reviews: 5
# registering information to dataframe...
# extracting information of Dr. Eleni Papagnanou...
# specialty: Ophthalmologist, overall_rating: 2.2, no_reviews: 3
# registering information to dataframe...
# extracting information of Dr. David Desjardins...
# specialty: Ophthalmologist, overall_rating: 3.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Mhin The La...
# specialty: Ophthalmologist, overall_rating: 3.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. George Achkar...
# specialty: Ophthalmologist, overall_rating: 2.5, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Paul Harasimovitch...
# specialty: Ophthalmologist, overall_rating: 1.8, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Arthur Labelle...
# specialty: Ophthalmologist, overall_rating: 5.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Robert C Polomeno...
# specialty: Ophthalmologist, overall_rating: 1.3, no_reviews: 2
# registering information to dataframe...
# extracting information of Dr. Francine Mathieu Millaire...
# specialty: Ophthalmologist, overall_rating: 1.1, no_reviews: 3
# registering information to dataframe...
# extracting information of Dr. C Belanger...
# specialty: Ophthalmologist, overall_rating: 1.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Sylvie Montplaisir...
# specialty: Ophthalmologist, overall_rating: 1.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Elie Khoury...
# specialty: Ophthalmologist, overall_rating: 1.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Margaret Taboul...
# specialty: Ophthalmologist, overall_rating: 1.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. Nguyen Nguyen Tuan Quynh Tram...
# specialty: Ophthalmologist, overall_rating: 1.0, no_reviews: 1
# registering information to dataframe...
# extracting information of Dr. David Leberer...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Pop Mihai...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. G El Lashkar...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Jean Daniel Harbour...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Duval Ophtamologiste...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Bryan P. Arthurs...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Alli Hafez...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. W. E. S Connolly...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Ouynh Nguyen...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Lucie Khoury...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. S Linley...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. A Mydlarski...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Marie-Carole Boucher...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Leon Salomon...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Pierre Brais...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Marie-Michele Cayer...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Stephen Silver...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Stephen Fichman...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Corriveau Louis-A...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Gisele Lee...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Michelle Gabon...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. F Rezende...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Christian Perreaultlt...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Louis Corriveau...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Sacre Coeur Eye...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Sophie Leduc...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Pierre Laflamme...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. H Mihalovits...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. N Guilbault...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Mark Lesk...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Francine Millaire...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Pierre Brais...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Lyne Chevrette...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. César HÃ©rÃ©dia...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. A Khan...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. S Gagne...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Clemence Lemire...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. L Bertolo...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Johanna Chremis...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Roch Gagnon...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. W E S Connolly...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Sainte-Marie Pierre...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Wes Connoly...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Louis Corriveau...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Wajszilber Marcello...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Albert Albert...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. S Khoury...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Fulvio Rezende...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Paul Thompson...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Sylver Barry...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Chaput Gilles...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. M Kaputsta...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. M. Silvestri...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Nicole Robillard...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. K Luneau...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. ---- Laflamme...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Jean-Louis Jacobs...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Jeandaniel Harbour...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Conrad Cavalek...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Franco Rezende...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Eugène N. Kladky...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Decepoil...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Chtistian Ferremo...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Marcel Amyot...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. El Aschkar...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. E Svare...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Ghislaine Turssot...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Marc André Réhaume...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Dinh Ba-Hiep...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. M. Sebag...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Szigiato...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Don Boghen...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Alo Taibi Majed...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Michael Kapsta...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Carole Boucher...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Johanne Johanne Menassa...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Lord Frederic...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Patrice Archambault...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Li-Wei Lin...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. David De Silver...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Brochu Jocelyne...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Paul Harrasymovich...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Clinique Michel Pop...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Solomon Leon...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Paul P.Thompson...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Antoine Azar...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Lawrence Jaworski...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Guiseppe Maiolo...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Basmadtian...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Line Chevrette...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Paul Harasymowyc...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Kurt Chirmer...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Sam Phemus...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. A. Mwuilambwé...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Perrrier Manuel...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Stephen Fishman...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Marie Lucie Khouri...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Gilles Chaput...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Salomon...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Bryan Anthuis...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Mickael Sebag...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Sebastian Olivier...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Melissa Antaki...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# extracting information of Dr. Fatma Zaguia...
# specialty: Ophthalmologist, overall_rating: , no_reviews:
# registering information to dataframe...
# saving data to csv file...

# %% [markdown]
# # Analyzer Code

# %%
dtype_dict = {
    'Doctor name': 'str',
    'Specialty': 'str',
    'Overall rating': 'float',
    'No. of reviews': 'int',
    'Reviews': 'str',
    'Review rating': 'float'
}

doctors_data = pd.read_csv(f'{DOCTOR_SPECIALTY}_{DOCTOR_LOCATION}.csv', dtype=dtype_dict)

# %%
def get_doctors_with_N_or_more_reviews(dataframe, N):
    return dataframe[dataframe['No. of reviews'] >= N]

def get_doctors_with_X_or_higher_rating(dataframe, X):
    return dataframe[dataframe['Overall rating'] >= X]

def get_doctors_with_experience_in_disease(dataframe):
    pattern = '|'.join(DISEASE_KEYWORDS)
    reviews_mentioning_disease = dataframe['Reviews'].str.contains(pattern, case=False, na=False)
    doctors_with_experience_in_disease = dataframe.loc[reviews_mentioning_disease, 'Doctor name'].unique()
    return dataframe[dataframe['Doctor name'].isin(doctors_with_experience_in_disease)]

def group_by_doctor_names(dataframe):
    return dataframe.groupby('Doctor name').agg({
        'Overall rating': 'first',
        'Specialty': 'first',
        'No. of reviews': 'first',
        'Reviews': lambda x: list(x),
        'Review rating': lambda x: list(x)
    })

def get_N_highest_rated_reviews(dataframe, N):
    def get_top_reviews(row):
        reviews_with_ratings = list(zip(row['Reviews'], row['Review rating']))
        top_reviews = sorted(reviews_with_ratings, key=lambda x:x[1], reverse=True)[:N]
        return [(rating, review) for review, rating in top_reviews]
    dataframe[f'Top {N} reviews'] = dataframe.apply(get_top_reviews, axis=1)
    return dataframe

def get_N_lowest_rated_reviews(dataframe, N):
    def get_bottom_reviews(row):
        reviews_with_ratings = list(zip(row['Reviews'], row['Review rating']))
        bottom_reviews = sorted(reviews_with_ratings, key=lambda x:x[1])[:N]
        return [(rating, review) for review, rating in bottom_reviews]
    dataframe[f'Bottom {N} reviews'] = dataframe.apply(get_bottom_reviews, axis=1)
    return dataframe

def get_reviews_mentioning_disease(dataframe):
    def get_disease_reviews(row):
        reviews_with_ratings = list(zip(row['Reviews'], row['Review rating']))
        return [(rating, review) for review, rating in reviews_with_ratings if not pd.isna(review) and any(disease.lower() in review.lower() for disease in DISEASE_KEYWORDS)]
    dataframe['Reviews mentioning disease'] = dataframe.apply(get_disease_reviews, axis=1)
    dataframe['No. of reviews mentioning disease'] = dataframe['Reviews mentioning disease'].apply(len)
    dataframe['Percentage of reviews mentioning disease'] = dataframe.apply(lambda row: round(row['No. of reviews mentioning disease'] / len(row['Reviews']) * 100, 1), axis=1)
    return dataframe

# %%
def summarize_doctor_reviews_using_GPT(dataframe, API_key, N):
    if API_key == "": return dataframe
    import os
    import time
    import openai
    os.environ["OPENAI_API_KEY"] = API_key
    client = openai.OpenAI()
    def _query_llm(prompt, client, temperature=1, max_tokens=300):
        while True:
          try:
            completion = client.chat.completions.create(
              model='gpt-4o',
              messages=[
                {"role": "system", "content": "You are a helpful assistant that summarize patient reviews about doctors to help them make decisions about their illnesses."},
                {"role": "user", "content": prompt}
              ],
              n=1,
              temperature=temperature,
              max_tokens=max_tokens,
            )
            generations = [choice.message.content for choice in completion.choices]
            return generations
          except openai.RateLimitError as e:
            if 'Rate limit reached for requests' in str(e):
              print('OpenAI API request exceeded rate limit:\nRetrying in 60 sec...')
              time.sleep(60)
            else:
              print('You exceeded your current quota, please check your plan and billing details.')
              break
          except openai.APIError as e:
            print(f'OpenAI API error:\n{e}')
            break
          except Exception as e:
            print(f'OpenAI API call unsuccessful with following error:\n{e}')
            break

    def summarize(row):
        gpt_prompt = f"Please summarize the doctor based on patient reviews. The reviews are out of 5. Please summarize succinctly based on all the reviews and not individually. Up to {N} top reviews, {N} bottom reviews and all the reviews concerning a relevant disease are given below: \n"
        for top_review in row[f'Top {N} reviews']:
            gpt_prompt += f"top review: {top_review}\n"
        for bottom_review in row[f'Bottom {N} reviews']:
            gpt_prompt += f"bottom review: {bottom_review}\n"
        for review_mentioning_disease in row['Reviews mentioning disease']:
            gpt_prompt += f"reviews mentioning disease: {review_mentioning_disease}\n"
        gpt_prompt += "Please pay more attention to the reviews mentioning the relevant disease and the bottom reviews. In case of bottom reviews, please make a judgement on whether they are generalizable or exceptions.\n"
        gpt_prompt
    
        summary = _query_llm(gpt_prompt, client)
        return summary

    dataframe['GPT summary of doctor'] = dataframe.apply(summarize, axis=1)
    return dataframe

# %%
# first, get doctors with 5 or more reviews
filtered_doctors_data = get_doctors_with_N_or_more_reviews(doctors_data, MIN_NUM_RATINGS_THRESHOLD)
# second, get doctors with a rating higher than 4
filtered_doctors_data = get_doctors_with_X_or_higher_rating(filtered_doctors_data, MIN_OVERALL_RATING_THRESHOLD)
# third, get doctors who has experience treating a disease based on keywords
filtered_doctors_data = get_doctors_with_experience_in_disease(filtered_doctors_data)
filtered_doctors_data = group_by_doctor_names(filtered_doctors_data)
# fourth, get top 3 review, bottom 3 reviews and all reviews mentioning disease for each doctor
filtered_doctors_data = get_N_highest_rated_reviews(filtered_doctors_data, NUM_TOP_AND_BOTTOM_REVIEWS_TO_ANALYZE)
filtered_doctors_data = get_N_lowest_rated_reviews(filtered_doctors_data, NUM_TOP_AND_BOTTOM_REVIEWS_TO_ANALYZE)
filtered_doctors_data = get_reviews_mentioning_disease(filtered_doctors_data)
# (OPTIONAL) fifth, let chatGPT summarize a doctor based on top comments, bottom comments and comments mentioning your disease, requires openai API key
filtered_doctors_data = summarize_doctor_reviews_using_GPT(filtered_doctors_data, OPENAI_API_KEY, NUM_TOP_AND_BOTTOM_REVIEWS_TO_ANALYZE)
# last, rank doctors based on rating
top_doctors = filtered_doctors_data.sort_values('Overall rating', ascending=False).head(NUM_DOCTORS_TO_RETRIEVE)

# %%
top_doctors.to_csv(f'top_{DOCTOR_SPECIALTY}_in_{DOCTOR_LOCATION}.csv')
top_doctors
# Out:
#                             Overall rating        Specialty  No. of reviews  \
# Doctor name
# Dr. Rachel Trussart                    5.0  Ophthalmologist              19
# Dr. Amer Omar                          4.9  Ophthalmologist              24
# Dr. Darren L. Albert                   4.8  Ophthalmologist             188
# Dr. Marc Andre Rheaume                 4.8  Ophthalmologist              30
# Dr. Shawn Cohen                        4.7  Ophthalmologist             105
# Dr. Sébastien Olivier                  4.7  Ophthalmologist              42
# Dr. Jean-Daniel Arbour                 4.7  Ophthalmologist              16
# Dr. David Lederer                      4.6  Ophthalmologist              49
# Dr. Paul Thompson                      4.6  Ophthalmologist              19
# Dr. Mounir Bashour                     4.6  Ophthalmologist             116
# Dr. Karim Hammamji                     4.6  Ophthalmologist               9
# Dr. Stephane Meere                     4.5  Ophthalmologist              22
# Dr. Devinder Cheema                    4.5  Ophthalmologist              72
# Dr. Johanne Menassa                    4.5  Ophthalmologist              58
# Dr. Marino J Discepola                 4.5  Ophthalmologist             171
# Dr. Ali Hafez                          4.5  Ophthalmologist              22
# Dr. Mila Oh                            4.4  Ophthalmologist               7
# Dr. Manuel Perrier                     4.4  Ophthalmologist              66
# Dr. Julius E. S. Gomolin               4.4  Ophthalmologist              40
# Dr. Laurence Jaworski                  4.4  Ophthalmologist               9
# Dr. Conrad C. Kavalec                  4.4  Ophthalmologist             114
# Dr. Gilles Marcil                      4.4  Ophthalmologist               9
# Dr. Chaim Edelstein                    4.3  Ophthalmologist             172
# Dr. Renaud Duval                       4.3  Ophthalmologist               7
# Dr. Louis Racine                       4.2  Ophthalmologist              40
# Dr. Michele Mabon                      4.1  Ophthalmologist              20
# Dr. Girair Basmadjian                  4.1  Ophthalmologist              16
# Dr. Flavio Rezende                     4.1  Ophthalmologist              15
# Dr. Marie-Lyne Belair                  4.1  Ophthalmologist              16
5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# Dr. Amer Omar               [5.0, 5.0, 3.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# Dr. Darren L. Albert        [5.0, 4.5, 5.0, 4.5, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# Dr. Marc Andre Rheaume      [5.0, 5.0, 5.0, 4.0, 5.0, 5.0, 5.0, 4.0, 5.0, ...
# Dr. Shawn Cohen             [5.0, 5.0, 5.0, 5.0, 1.0, 5.0, 5.0, 5.0, 5.0, ...
# Dr. Sébastien Olivier       [4.5, 5.0, 4.5, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# Dr. Jean-Daniel Arbour      [5.0, 5.0, 5.0, 2.0, 4.5, 5.0, 5.0, 5.0, 5.0, ...
# Dr. David Lederer           [5.0, 1.0, 5.0, 5.0, 5.0, 3.5, 5.0, 5.0, 5.0, ...
# Dr. Paul Thompson           [5.0, 5.0, 5.0, 3.0, 5.0, 5.0, 5.0, 5.0, 4.5, ...
# Dr. Mounir Bashour          [1.0, 3.0, 5.0, 5.0, 5.0, 2.0, 5.0, 1.5, 2.0, ...
# Dr. Karim Hammamji              [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 1.5, 5.0]
# Dr. Stephane Meere          [4.5, 4.5, 4.0, 4.5, 5.0, 4.5, 4.5, 5.0, 5.0, ...
# Dr. Devinder Cheema         [5.0, 5.0, 5.0, 5.0, 4.5, 5.0, 5.0, 4.0, 5.0, ...
# Dr. Johanne Menassa         [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# Dr. Marino J Discepola      [5.0, 5.0, 4.5, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# Dr. Ali Hafez               [5.0, 5.0, 4.5, 3.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# Dr. Mila Oh                               [5.0, 3.5, 4.5, 4.5, 5.0, 4.0, 5.0]
# Dr. Manuel Perrier          [5.0, 1.0, 5.0, 2.5, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# Dr. Julius E. S. Gomolin    [5.0, 5.0, 3.0, 5.0, 5.0, 5.0, 5.0, 4.5, 4.5, ...
# Dr. Laurence Jaworski           [5.0, 5.0, 3.5, 5.0, 5.0, 5.0, 4.0, 3.5, 4.5]
# Dr. Conrad C. Kavalec       [4.5, 4.5, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# Dr. Gilles Marcil               [4.5, 4.0, 4.5, 5.0, 4.0, 5.0, 4.5, 4.5, 4.5]
# Dr. Chaim Edelstein         [5.0, 5.0, 2.0, 4.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...
# Dr. Renaud Duval                          [1.0, 5.0, 5.0, 4.5, 5.0, 5.0, 5.0]
# Dr. Louis Racine            [5.0, 5.0, 5.0, 2.5, 1.0, 4.5, 5.0, 5.0, 5.0, ...
# Dr. Michele Mabon           [4.0, 5.0, 5.0, 5.0, 5.0, 5.0, 2.5, 1.0, 5.0, ...
# Dr. Girair Basmadjian       [5.0, 5.0, 3.5, 5.0, 4.5, 2.0, 1.0, 5.0, 5.0, ...
# Dr. Flavio Rezende          [3.0, 4.0, 2.0, 1.5, 4.5, 5.0, 2.5, 5.0, 4.5, ...
# Dr. Marie-Lyne Belair       [2.0, 4.5, 5.0, 4.5, 5.0, 3.0, 5.0, 4.0, 4.0, ...
